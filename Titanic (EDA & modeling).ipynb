# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('train.csv')
train.head(7)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %%
test = pd.read_csv('test.csv')
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
train.drop(['PassengerId', 'Ticket', 'Cabin'], inplace = True, axis =1)
test.drop([ 'Ticket', 'Cabin'], inplace = True, axis =1)

# %%
test['fsize'] = test['Parch'] + test['SibSp']+1
train['fsize'] = train['Parch'] + train['SibSp']+1

# %%
train['Embarked'].fillna('S',inplace = True)

# %%
train['Title'] = train.Name.apply(lambda x : x.split(',')[1].split('.')[0].strip())
test['Title'] = test.Name.apply(lambda x : x.split(',')[1].split('.')[0].strip())

# %%
test.Title.value_counts()
# Out:
# Mr        240
# Miss       78
# Mrs        72
# Master     21
# Col         2
# Rev         2
# Dona        1
# Ms          1
# Dr          1
# Name: Title, dtype: int64

# %%
train.Title.value_counts()
# Out:
# Mr              517
# Miss            182
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Major             2
# Mlle              2
# Col               2
# the Countess      1
# Mme               1
# Jonkheer          1
# Ms                1
# Lady              1
# Sir               1
# Capt              1
# Don               1
# Name: Title, dtype: int64

# %%
lst_titles = list(train.Title.value_counts().index)
lst_titles
# Out:
# ['Mr',
#  'Miss',
#  'Mrs',
#  'Master',
#  'Dr',
#  'Rev',
#  'Major',
#  'Mlle',
#  'Col',
#  'the Countess',
#  'Mme',
#  'Jonkheer',
#  'Ms',
#  'Lady',
#  'Sir',
#  'Capt',
#  'Don']

# %%
k={}
for i in lst_titles[:6]:  
    k[i]=lst_titles.index(i)
for i in lst_titles[6:]:  
    k[i]=6
k
# Out:
# {'Mr': 0,
#  'Miss': 1,
#  'Mrs': 2,
#  'Master': 3,
#  'Dr': 4,
#  'Rev': 5,
#  'Major': 6,
#  'Mlle': 6,
#  'Col': 6,
#  'the Countess': 6,
#  'Mme': 6,
#  'Jonkheer': 6,
#  'Ms': 6,
#  'Lady': 6,
#  'Sir': 6,
#  'Capt': 6,
#  'Don': 6}

# %%
train['Title']=train['Title'].map(k)
test['Title']=test['Title'].map(k)

# %%
test.isnull().sum()
# Out:
# PassengerId     0
# Pclass          0
# Name            0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Fare            1
# Embarked        0
# fsize           0
# Title           1
# dtype: int64

# %%
test['Title'][test['Title'].isnull()]
# Out:
# 414   NaN
# Name: Title, dtype: float64

# %%
test.iloc[414]
# Out:
# PassengerId                            1306
# Pclass                                    1
# Name           Oliva y Ocana, Dona. Fermina
# Sex                                  female
# Age                                      39
# SibSp                                     0
# Parch                                     0
# Fare                                  108.9
# Embarked                                  C
# fsize                                     1
# Title                                   NaN
# Name: 414, dtype: object

# %%
test.Title.fillna('1', inplace = True)

# %%
test.iloc[414]
# Out:
# PassengerId                            1306
# Pclass                                    1
# Name           Oliva y Ocana, Dona. Fermina
# Sex                                  female
# Age                                      39
# SibSp                                     0
# Parch                                     0
# Fare                                  108.9
# Embarked                                  C
# fsize                                     1
# Title                                     1
# Name: 414, dtype: object

# %%
#test.isnull().sum()
train.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      0
# fsize         0
# Title         0
# dtype: int64

# %%
grp = ['SibSp','Parch','Sex','Title']
train['Age']=train['Age'].fillna(train.groupby(grp)['Age'].transform('median'))
test['Age']=test['Age'].fillna(test.groupby(grp)['Age'].transform('median'))

# %%
test.isnull().sum()
#train.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            7
# SibSp          0
# Parch          0
# Fare           1
# Embarked       0
# fsize          0
# Title          0
# dtype: int64

# %%
test.head(16)
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 3           895       3                                   Wirz, Mr. Albert
# 4           896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5           897       3                         Svensson, Mr. Johan Cervin
# 6           898       3                               Connolly, Miss. Kate
# 7           899       2                       Caldwell, Mr. Albert Francis
# 8           900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9           901       3                            Davies, Mr. John Samuel
# 10          902       3                                   Ilieff, Mr. Ylio
# ...

# %%
test.isnull().sum()
#train.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            7
# SibSp          0
# Parch          0
# Fare           1
# Embarked       0
# fsize          0
# Title          0
# dtype: int64

# %%
test['Age'].fillna(test['Age'].median , inplace = True)

# %%
train['Age'].fillna(train['Age'].median , inplace = True)

# %%
train.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# fsize       0
# Title       0
# dtype: int64

# %%
train.head(15)
# Out:
#     Survived  Pclass                                               Name  \
# 0          0       3                            Braund, Mr. Owen Harris
# 1          1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1       3                             Heikkinen, Miss. Laina
# 3          1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0       3                           Allen, Mr. William Henry
# 5          0       3                                   Moran, Mr. James
# 6          0       1                            McCarthy, Mr. Timothy J
# 7          0       3                     Palsson, Master. Gosta Leonard
# 8          1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9          1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10         1       3                    Sandstrom, Miss. Marguerite Rut
# 11         1       1                           Bonnell, Miss. Elizabeth
# ...

# %%
train['Sex'] = train['Sex'].map({'male':0, 'female':1})
test['Sex'] = test['Sex'].map({'male':0, 'female':1})

# %%
train['Embarked'] = train['Embarked'].map ({'S':0, 'C':1, 'Q':2})

# %%
test['Embarked'] = test['Embarked'].map ({'S':0, 'C':1, 'Q':2})

# %%
train['IsAlone'] = 0

# %%
train.loc[train['fsize'] == 1, 'IsAlone'] = 1

# %%
test['IsAlone'] = 0

# %%
test.loc[test['fsize'] == 1, 'IsAlone'] = 1

# %%
train.head()
# Out:
#    Survived  Pclass                                               Name  Sex  \
# 0         0       3                            Braund, Mr. Owen Harris    0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1
# 2         1       3                             Heikkinen, Miss. Laina    1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1
# 4         0       3                           Allen, Mr. William Henry    0
#
#   Age  SibSp  Parch     Fare  Embarked  fsize  Title  IsAlone
# 0  22      1      0   7.2500         0      2      0        0
# 1  38      1      0  71.2833         1      2      2        0
# 2  26      0      0   7.9250         0      1      1        1
# 3  35      1      0  53.1000         0      2      2        0
# 4  35      0      0   8.0500         0      1      0        1

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    0
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    1
# 2          894       2                     Myles, Mr. Thomas Francis    0
# 3          895       3                              Wirz, Mr. Albert    0
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
#
#     Age  SibSp  Parch     Fare  Embarked  fsize Title  IsAlone
# 0  34.5      0      0   7.8292         2      1     0        1
# 1    47      1      0   7.0000         0      2     2        0
# 2    62      0      0   9.6875         2      1     0        1
# 3    27      0      0   8.6625         0      1     0        1
# 4    22      1      1  12.2875         0      3     2        0

# %%
train.drop(['Parch','SibSp','Name'], axis =1, inplace = True)
test.drop(['Parch','SibSp','Name'], axis =1, inplace = True)

# %%
train.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# Fare        0
# Embarked    0
# fsize       0
# Title       0
# IsAlone     0
# dtype: int64

# %%
test['Fare']= test['Fare'].fillna(test['Fare'].median())

# %%
def round_five(x):
    return int(5 * round(float(x)/5))

# %%
test['Fare'] = test['Fare'].apply(lambda x: round_five(x))
train['Fare'] = train['Fare'].apply(lambda x: round_five(x))

# %%
test.Fare.value_counts()
# Out:
# 10     139
# 15      63
# 25      39
# 5       33
# 30      25
# 20      19
# 60      10
# 40       9
# 80       7
# 55       6
# 50       6
# 75       6
# 135      6
# 210      5
# 260      5
# 70       5
# 35       4
# 45       4
# 65       4
# 220      3
# 85       3
# 0        2
# 265      2
# 95       2
# 150      2
# 165      2
# 90       1
# 105      1
# 110      1
# 145      1
# 230      1
# 250      1
# 510      1
# Name: Fare, dtype: int64

# %%
train.head(10)
# Out:
#    Survived  Pclass  Sex Age  Fare  Embarked  fsize  Title  IsAlone
# 0         0       3    0  22     5         0      2      0        0
# 1         1       1    1  38    70         1      2      2        0
# 2         1       3    1  26    10         0      1      1        1
# 3         1       1    1  35    55         0      2      2        0
# 4         0       3    0  35    10         0      1      0        1
# 5         0       3    0  29    10         2      1      0        1
# 6         0       1    0  54    50         0      1      0        1
# 7         0       3    0   2    20         0      5      3        0
# 8         1       3    1  27    10         0      3      2        0
# 9         1       2    1  14    30         1      2      2        0

# %%
test.head(10)
# Out:
#    PassengerId  Pclass  Sex   Age  Fare  Embarked  fsize Title  IsAlone
# 0          892       3    0  34.5    10         2      1     0        1
# 1          893       3    1    47     5         0      2     2        0
# 2          894       2    0    62    10         2      1     0        1
# 3          895       3    0    27    10         0      1     0        1
# 4          896       3    1    22    10         0      3     2        0
# 5          897       3    0    14    10         0      1     0        1
# 6          898       3    1    30    10         2      1     1        1
# 7          899       2    0    26    30         0      3     0        0
# 8          900       3    1    18     5         1      1     2        1
# 9          901       3    0    21    25         0      3     0        0

# %%
trainn=train.copy()
testt=test.copy()

# %%
trainn.to_csv('Processed_train_data.csv')
testt.to_csv('Processed_test_data.csv')

# %%
for i in list(trainn.columns):

    trainn[i] = pd.to_numeric(trainn[i], errors='coerce')

# %%
for i in list(testt.columns):

    testt[i] = pd.to_numeric(testt[i], errors='coerce')
## to convert all values to numeric -- error mostly caused due to df.column.fillna()

# %%
testt.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Sex            0
# Age            0
# Fare           0
# Embarked       0
# fsize          0
# Title          0
# IsAlone        0
# dtype: int64

# %%
testt['Age'] = testt['Age'].fillna(testt.Age.median())

# %%
train.head(8)
# Out:
#    Survived  Pclass  Sex Age  Fare  Embarked  fsize  Title  IsAlone
# 0         0       3    0  22     5         0      2      0        0
# 1         1       1    1  38    70         1      2      2        0
# 2         1       3    1  26    10         0      1      1        1
# 3         1       1    1  35    55         0      2      2        0
# 4         0       3    0  35    10         0      1      0        1
# 5         0       3    0  29    10         2      1      0        1
# 6         0       1    0  54    50         0      1      0        1
# 7         0       3    0   2    20         0      5      3        0

# %%
test.head(8)
# Out:
#    PassengerId  Pclass  Sex   Age  Fare  Embarked  fsize Title  IsAlone
# 0          892       3    0  34.5    10         2      1     0        1
# 1          893       3    1    47     5         0      2     2        0
# 2          894       2    0    62    10         2      1     0        1
# 3          895       3    0    27    10         0      1     0        1
# 4          896       3    1    22    10         0      3     2        0
# 5          897       3    0    14    10         0      1     0        1
# 6          898       3    1    30    10         2      1     1        1
# 7          899       2    0    26    30         0      3     0        0

# %% [markdown]
# # Prediction

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(trainn.drop(['Survived'], axis =1), trainn.Survived, test_size = 0.2)

# %%
print(len(X_test))
print(len(X_train))

# %%
y_test.head(10)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=25, max_depth=8)
model.fit(X_train , y_train)

# %%
    model.score(X_test,y_test)

# %%
predictions = model.predict(testt.drop('PassengerId', axis=1))

# %%
output = pd.DataFrame({'PassengerId': testt.PassengerId, 'Survived': predictions})

# %%
output.to_csv("Result_Titanic__1.csv")
